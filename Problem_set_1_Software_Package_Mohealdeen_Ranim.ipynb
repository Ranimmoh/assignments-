# %% [markdown]
# Dataset: https://archive.ics.uci.edu/dataset/352/online+retail
# analysig reatil sttore to identify trends , performance ...etc

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
RS = pd.read_csv("Online Retail.csv",on_bad_lines='skip')

# %%
RS
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 313719    564534     82582            AREA PATROLLED METAL SIGN         2
# 313720    564534     21034         REX CASH+CARRY JUMBO SHOPPER         2
# 313721    564534     22084               PAPER CHAIN KIT EMPIRE         1
# 313722    564535     23321          SMALL WHITE HEART OF WICKER        24
# 313723    564535     23322          LARGE WHITE HEART OF WICKER        12
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
RS.isnull().sum()
# Out:
# InvoiceNo          0
# StockCode          0
# Description     1125
# Quantity           0
# InvoiceDate        0
# UnitPrice          1
# CustomerID     85327
# Country            1
# dtype: int64

# %%
RS= RS.dropna(subset=['Description'],axis=0) # DROPING NULL VALUES IN DESCRIPTION AND CUSTOMERID COLUMN
RS = RS.dropna(subset=['CustomerID'],axis=0)

# %%
RS.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
RS.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  228397.000000  228397.000000  228397.000000
# mean       12.647272       3.674507   15280.441788
# std       225.411656      89.215285    1725.949845
# min    -74215.000000       0.000000   12346.000000
# 25%         2.000000       1.250000   13865.000000
# 50%         6.000000       1.950000   15150.000000
# 75%        12.000000       3.750000   16813.000000
# max     74215.000000   38970.000000   18287.000000

# %%
RS
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 313718    564534     21165        BEWARE OF THE CAT METAL SIGN          4
# 313719    564534     82582            AREA PATROLLED METAL SIGN         2
# 313720    564534     21034         REX CASH+CARRY JUMBO SHOPPER         2
# 313721    564534     22084               PAPER CHAIN KIT EMPIRE         1
# 313722    564535     23321          SMALL WHITE HEART OF WICKER        24
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# cleaning data :

# %%
#Quantity must be positive number
for i in RS["Quantity"]:
  if(i<0):
    i=RS[RS["Quantity"]==i].index
    RS=RS.drop(i)

#unit price column has positive number we dont really need to run this code
  if(i<0):
    i=RS[RS["UnitPrice"]==i].index
    RS=RS.drop(i)

# %% [markdown]
# product performance:

# %%
_ = plt.figure(figsize=(20, 10))
plt.plot(Range,RS["Quantity"][:600],color='blue' )
plt.show()

# %%
Range =  np.arange(0,600)
_ = plt.figure(figsize=(20, 10))
plt.plot(Range,RS["UnitPrice"][:600], color='blue')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

labels = np.arange(0, 228397)
quantity_values = RS["Quantity"]
plt.plot(labels, quantity_values, color='blue')
plt.show()

# %%
labels = np.arange(0, 228397)
quantity_values = RS["UnitPrice"]
plt.plot(labels, quantity_values, color='blue')
plt.show()
